# %% [markdown]
# <a href="https://colab.research.google.com/github/SoulSolomon21/colab-notebooks/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
x = np.array([[-1], [0], [1], [2], [3], [4], [5]], dtype=int)
y = np.array([[-2], [1], [4], [7], [10], [13], [16]], dtype=int)

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
custom_optimizer = keras.optimizers.SGD(learning_rate=0.01)
model.compile(optimizer=custom_optimizer, loss='mean_squared_error')

# %%
model.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 636ms/step - loss: 192.7617
# Epoch 2/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 132.6016
# Epoch 3/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 91.2192
# Epoch 4/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 62.7535
# Epoch 5/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 43.1728
# Epoch 6/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 29.7038
# Epoch 7/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 20.4387
# Epoch 8/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 14.0655
# Epoch 9/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 9.6814
# Epoch 10/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.6657
# Epoch 11/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.5911
# Epoch 12/1000
# ...

# %%
input_data = np.array([[100], [34]], dtype=int)

# %%
predictions = model.predict(input_data)
print(predictions)
# Out:
# 1/1 [==============================] - 0s 82ms/step
# [[300.99948]
#  [102.99984]]
